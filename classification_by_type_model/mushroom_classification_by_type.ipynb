# %% [markdown]
# # Нейронная сеть для классификации грибов (по видам)
# ## Импорт библиотек и настройки

# %%
# Импортируем необходимые библиотеки
import os
import shutil
import pandas as pd

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.python.framework.config import list_physical_devices, set_memory_growth

# %%
# Разрешаем загружать усеченные изображения
# чтобы исключить ошибку "Image File is truncated"
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# Найстроки отображения объектов
plt.rcParams['figure.figsize'] = 12, 8
plt.rcParams.update({'font.size': 12})

# %%
# Обучать будем на GPU
physical_devices = list_physical_devices('GPU')
print(f'Количество доступных GPU: {len(physical_devices)}')

if len(physical_devices) > 0:
    set_memory_growth(physical_devices[0], True)
# Out:
# Количество доступных GPU: 0

# %%
# TensorFlow константы
AUTOTUNE = tf.data.experimental.AUTOTUNE
IMG_SIZE = 227
BATCH_SIZE = 64

# %% [markdown]
# ## Загрузка и обработка данных

# %%
# Подключаем гугл диск с датасетом
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Путь к папке с 9 классами изображений
data_path = '/content/drive/MyDrive/ColabNotebooks/neuro_project/Mushrooms'

# %%
# Разделим изображения в пропорции 75%/15%/10% и сохраним во временные папки
for subfolder in os.listdir(data_path):

    # Список всех файлов в текущей подпапке
    original_path = f'{data_path}/{subfolder}'
    original_data = os.listdir(original_path)

    # Количество образцов в каждой группе
    n_samples = len(original_data)
    train_samples = int(n_samples * 0.75)
    valid_samples = int(n_samples * 0.9)

    train_path = f'/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/train/{subfolder}'
    valid_path = f'/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/valid/{subfolder}'
    test_path = f'/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/test/{subfolder}'

    # Новая подпапка классов для обучения
    os.chdir('/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/train')
    os.mkdir(subfolder)

    # Тренировочные изображения
    for image in range(train_samples):
        original_file = f'{original_path}/{original_data[image]}'
        new_file = f'{train_path}/{original_data[image]}'
        shutil.copyfile(original_file, new_file)

    # Новая подпапка класса для валидации
    os.chdir('/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/valid')
    os.mkdir(subfolder)

    # Изображения для валидации:
    for image in range(train_samples, valid_samples):
        original_file = f'{original_path}/{original_data[image]}'
        new_file = f'{valid_path}/{original_data[image]}'
        shutil.copyfile(original_file, new_file)

    # Новая подпапка класса для теста
    os.chdir('/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/test')
    os.mkdir(subfolder)

    # Изображения для теста:
    for image in range(valid_samples, n_samples):
        original_file = f'{original_path}/{original_data[image]}'
        new_file = f'{test_path}/{original_data[image]}'
        shutil.copyfile(original_file, new_file)

# %%
# Посмотрим на примеры каждого из классов
nrows = 3
ncols = 3

pos = 0

for subfolder in os.listdir(data_path):

    image_file = os.listdir(os.path.join(data_path, subfolder))[0]

    fig = plt.gcf()
    fig.set_size_inches(ncols * 4, nrows * 4)

    pos += 1
    sp = plt.subplot(nrows, ncols, pos)

    cur_image = mpimg.imread(os.path.join(data_path, subfolder, image_file))
    plt.imshow(cur_image)
    plt.title(subfolder)
    plt.axis('Off')

# %%
# Создадим тестовый, валидационный и тренировочный наборы данных
train_generator = ImageDataGenerator(preprocessing_function=preprocess_input)\
                    .flow_from_directory(directory='/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/train',
                                         target_size=(IMG_SIZE, IMG_SIZE),
                                         class_mode='categorical',
                                         batch_size=BATCH_SIZE,
                                         shuffle=True)
valid_generator = ImageDataGenerator(preprocessing_function=preprocess_input)\
                    .flow_from_directory(directory='/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/valid',
                                         target_size=(IMG_SIZE, IMG_SIZE),
                                         class_mode='categorical',
                                         batch_size=BATCH_SIZE,
                                         shuffle=True)
test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)\
                    .flow_from_directory(directory='/content/drive/MyDrive/ColabNotebooks/neuro_project/temp/test',
                                         target_size=(IMG_SIZE, IMG_SIZE),
                                         class_mode='categorical',
                                         batch_size=BATCH_SIZE,
                                         shuffle=True)
# Out:
# Found 3432 images belonging to 9 classes.
# Found 667 images belonging to 9 classes.
# Found 450 images belonging to 9 classes.

# %% [markdown]
# ## Создание модели

# %%
# Предварительно обученная модель классификации изображений EfficientNetB7 без финальных слоев
feature_model = tf.keras.applications.EfficientNetB7(weights='imagenet',
                                                     include_top=False,
                                                     input_shape=(IMG_SIZE, IMG_SIZE, 3),
                                                     pooling='avg')

feature_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 1s 0us/step
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 227, 227, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 227, 227, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 227, 227, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 229, 229, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 114, 114, 64)         1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 114, 114, 64)         256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 114, 114, 64)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 114, 114, 64)         576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 114, 114, 64)         256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 114, 114, 64)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 114, 114, 64)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 114, 114, 32)         2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 114, 114, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 114, 114, 32)         288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 114, 114, 32)         128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 114, 114, 32)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 114, 114, 32)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 114, 114, 32)         1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 114, 114, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 114, 114, 32)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 114, 114, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 114, 114, 32)         288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 114, 114, 32)         128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 114, 114, 32)         0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 114, 114, 32)         0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 114, 114, 32)         1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 114, 114, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 114, 114, 32)         0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 114, 114, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 114, 114, 32)         288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 114, 114, 32)         128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 114, 114, 32)         0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 114, 114, 32)         0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 114, 114, 32)         1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 114, 114, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 114, 114, 32)         0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 114, 114, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 114, 114, 192)        6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 114, 114, 192)        768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 114, 114, 192)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 115, 115, 192)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 57, 57, 192)          1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 57, 57, 192)          768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 57, 57, 192)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 57, 57, 192)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 57, 57, 48)           9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 57, 57, 288)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 57, 57, 288)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 57, 57, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 57, 57, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 57, 57, 288)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 57, 57, 288)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 57, 57, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 57, 57, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 57, 57, 288)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 57, 57, 288)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 57, 57, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 57, 57, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 57, 57, 288)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 57, 57, 288)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 57, 57, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 57, 57, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 57, 57, 288)          0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 57, 57, 288)          0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 57, 57, 48)           0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 57, 57, 48)           0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 57, 57, 288)          0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 57, 57, 288)          2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 57, 57, 288)          1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 57, 57, 288)          0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 57, 57, 288)          0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 57, 57, 48)           13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 57, 57, 48)           192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 57, 57, 48)           0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 57, 57, 48)           0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 57, 57, 288)          13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 57, 57, 288)          1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 57, 57, 288)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 61, 61, 288)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 29, 29, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 29, 29, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 29, 29, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 29, 29, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 29, 29, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 29, 29, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
# ...
#  tion)
#
#  block7a_se_squeeze (Global  (None, 2304)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 8, 8, 2304)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 8, 8, 640)            1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 8, 8, 3840)           2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 8, 8, 3840)           15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 8, 8, 3840)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 8, 8, 3840)           34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 8, 8, 3840)           15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 8, 8, 3840)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 8, 8, 3840)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 8, 8, 640)            2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 8, 8, 640)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 8, 8, 640)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 8, 8, 3840)           2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 8, 8, 3840)           15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 8, 8, 3840)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 8, 8, 3840)           34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 8, 8, 3840)           15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 8, 8, 3840)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 8, 8, 3840)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 8, 8, 640)            2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 8, 8, 640)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 8, 8, 640)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 8, 8, 3840)           2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 8, 8, 3840)           15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 8, 8, 3840)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 8, 8, 3840)           34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 8, 8, 3840)           15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 8, 8, 3840)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 8, 8, 3840)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 8, 8, 640)            2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 8, 8, 640)            2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 8, 8, 640)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 8, 8, 640)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 2560)           1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 2560)           10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 2560)           0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 2560)                 0         ['top_activation[0][0]']
#  ling2D)
#
# ==================================================================================================
# Total params: 64097687 (244.51 MB)
# Trainable params: 63786960 (243.33 MB)
# Non-trainable params: 310727 (1.19 MB)
# __________________________________________________________________________________________________

# %%
# Создадим новую модель и добавим последний слой для классификации
new_model = tf.keras.models.Sequential(
    [
        feature_model,
        tf.keras.layers.Dense(9, activation='softmax')
    ]
)

# %%
# Сделаем все слои исходной модели необучаемыми
new_model.layers[0].trainable = False

# %%
# Метрики и оптимизатор
new_model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
# Проверим архитектуру новой модели
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb7 (Functional  (None, 2560)              64097687
#  )
#
#  dense (Dense)               (None, 9)                 23049
#
# =================================================================
# Total params: 64120736 (244.60 MB)
# Trainable params: 23049 (90.04 KB)
# Non-trainable params: 64097687 (244.51 MB)
# _________________________________________________________________

# %%
# Добавим сallbacks
# Остановим обучение если метрика не улучшается
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=10,
                                              restore_best_weights=True)

# И будем снижать скорость обучения если метрика перестанет улучшаться
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',
                                                 factor=0.1,
                                                 mode='max',
                                                 cooldown=2,
                                                 patience=2,
                                                 min_lr=0)

# %%
# Обучим нашу модель
history = new_model.fit(train_generator,
                        validation_data=valid_generator,
                        epochs=50,
                        steps_per_epoch=79,
                        validation_steps=16,
                        verbose=2,
                        callbacks=[reduce_lr, early_stop],
                        use_multiprocessing=True,
                        workers=2)
# Out:
# Epoch 1/50
# 79/79 - 633s - loss: 1.1297 - accuracy: 0.6042 - val_loss: 0.8533 - val_accuracy: 0.7001 - lr: 0.0010 - 633s/epoch - 8s/step
# Epoch 2/50
# 79/79 - 82s - loss: 0.7978 - accuracy: 0.7287 - val_loss: 0.7422 - val_accuracy: 0.7214 - lr: 0.0010 - 82s/epoch - 1s/step
# Epoch 3/50
# 79/79 - 84s - loss: 0.6966 - accuracy: 0.7742 - val_loss: 0.6782 - val_accuracy: 0.7579 - lr: 0.0010 - 84s/epoch - 1s/step
# Epoch 4/50
# 79/79 - 78s - loss: 0.6270 - accuracy: 0.7975 - val_loss: 0.6432 - val_accuracy: 0.7579 - lr: 0.0010 - 78s/epoch - 982ms/step
# Epoch 5/50
# 79/79 - 79s - loss: 0.5845 - accuracy: 0.8081 - val_loss: 0.5914 - val_accuracy: 0.7974 - lr: 0.0010 - 79s/epoch - 1s/step
# Epoch 6/50
# 79/79 - 80s - loss: 0.5356 - accuracy: 0.8271 - val_loss: 0.5783 - val_accuracy: 0.8075 - lr: 0.0010 - 80s/epoch - 1s/step
# Epoch 7/50
# 79/79 - 79s - loss: 0.5082 - accuracy: 0.8393 - val_loss: 0.5573 - val_accuracy: 0.8085 - lr: 0.0010 - 79s/epoch - 1s/step
# Epoch 8/50
# 79/79 - 85s - loss: 0.4837 - accuracy: 0.8492 - val_loss: 0.5733 - val_accuracy: 0.7933 - lr: 0.0010 - 85s/epoch - 1s/step
# Epoch 9/50
# 79/79 - 80s - loss: 0.4686 - accuracy: 0.8488 - val_loss: 0.5138 - val_accuracy: 0.8227 - lr: 0.0010 - 80s/epoch - 1s/step
# Epoch 10/50
# 79/79 - 79s - loss: 0.4424 - accuracy: 0.8655 - val_loss: 0.5344 - val_accuracy: 0.8257 - lr: 0.0010 - 79s/epoch - 994ms/step
# Epoch 11/50
# 79/79 - 79s - loss: 0.4159 - accuracy: 0.8756 - val_loss: 0.5218 - val_accuracy: 0.8399 - lr: 0.0010 - 79s/epoch - 1s/step
# Epoch 12/50
# 79/79 - 85s - loss: 0.4052 - accuracy: 0.8738 - val_loss: 0.5099 - val_accuracy: 0.8349 - lr: 0.0010 - 85s/epoch - 1s/step
# Epoch 13/50
# 79/79 - 82s - loss: 0.3879 - accuracy: 0.8869 - val_loss: 0.4925 - val_accuracy: 0.8359 - lr: 0.0010 - 82s/epoch - 1s/step
# Epoch 14/50
# 79/79 - 79s - loss: 0.3718 - accuracy: 0.8919 - val_loss: 0.5038 - val_accuracy: 0.8349 - lr: 1.0000e-04 - 79s/epoch - 1s/step
# Epoch 15/50
# 79/79 - 82s - loss: 0.3653 - accuracy: 0.8938 - val_loss: 0.5060 - val_accuracy: 0.8419 - lr: 1.0000e-04 - 82s/epoch - 1s/step
# Epoch 16/50
# 79/79 - 85s - loss: 0.3678 - accuracy: 0.8928 - val_loss: 0.5203 - val_accuracy: 0.8338 - lr: 1.0000e-04 - 85s/epoch - 1s/step
# Epoch 17/50
# 79/79 - 81s - loss: 0.3694 - accuracy: 0.8943 - val_loss: 0.4774 - val_accuracy: 0.8490 - lr: 1.0000e-04 - 81s/epoch - 1s/step
# Epoch 18/50
# 79/79 - 81s - loss: 0.3714 - accuracy: 0.8897 - val_loss: 0.5047 - val_accuracy: 0.8369 - lr: 1.0000e-04 - 81s/epoch - 1s/step
# Epoch 19/50
# 79/79 - 84s - loss: 0.3669 - accuracy: 0.8959 - val_loss: 0.4992 - val_accuracy: 0.8409 - lr: 1.0000e-04 - 84s/epoch - 1s/step
# Epoch 20/50
# 79/79 - 85s - loss: 0.3657 - accuracy: 0.8946 - val_loss: 0.4866 - val_accuracy: 0.8480 - lr: 1.0000e-05 - 85s/epoch - 1s/step
# Epoch 21/50
# 79/79 - 80s - loss: 0.3668 - accuracy: 0.8935 - val_loss: 0.5185 - val_accuracy: 0.8369 - lr: 1.0000e-05 - 80s/epoch - 1s/step
# Epoch 22/50
# 79/79 - 85s - loss: 0.3594 - accuracy: 0.8996 - val_loss: 0.5004 - val_accuracy: 0.8409 - lr: 1.0000e-05 - 85s/epoch - 1s/step
# Epoch 23/50
# 79/79 - 84s - loss: 0.3635 - accuracy: 0.8936 - val_loss: 0.4905 - val_accuracy: 0.8531 - lr: 1.0000e-06 - 84s/epoch - 1s/step
# Epoch 24/50
# 79/79 - 78s - loss: 0.3657 - accuracy: 0.8961 - val_loss: 0.4974 - val_accuracy: 0.8419 - lr: 1.0000e-06 - 78s/epoch - 993ms/step
# Epoch 25/50
# 79/79 - 85s - loss: 0.3599 - accuracy: 0.8998 - val_loss: 0.4936 - val_accuracy: 0.8430 - lr: 1.0000e-06 - 85s/epoch - 1s/step
# Epoch 26/50
# 79/79 - 79s - loss: 0.3639 - accuracy: 0.8983 - val_loss: 0.4999 - val_accuracy: 0.8480 - lr: 1.0000e-07 - 79s/epoch - 998ms/step
# Epoch 27/50
# 79/79 - 84s - loss: 0.3698 - accuracy: 0.8897 - val_loss: 0.4968 - val_accuracy: 0.8460 - lr: 1.0000e-07 - 84s/epoch - 1s/step
# Epoch 28/50
# 79/79 - 85s - loss: 0.3650 - accuracy: 0.8940 - val_loss: 0.4853 - val_accuracy: 0.8521 - lr: 1.0000e-07 - 85s/epoch - 1s/step
# Epoch 29/50
# 79/79 - 79s - loss: 0.3668 - accuracy: 0.8924 - val_loss: 0.4987 - val_accuracy: 0.8419 - lr: 1.0000e-08 - 79s/epoch - 1s/step
# Epoch 30/50
# 79/79 - 86s - loss: 0.3614 - accuracy: 0.9010 - val_loss: 0.4871 - val_accuracy: 0.8470 - lr: 1.0000e-08 - 86s/epoch - 1s/step
# Epoch 31/50
# 79/79 - 84s - loss: 0.3648 - accuracy: 0.8988 - val_loss: 0.5078 - val_accuracy: 0.8430 - lr: 1.0000e-08 - 84s/epoch - 1s/step
# Epoch 32/50
# 79/79 - 85s - loss: 0.3663 - accuracy: 0.8953 - val_loss: 0.4701 - val_accuracy: 0.8501 - lr: 1.0000e-09 - 85s/epoch - 1s/step
# Epoch 33/50
# 79/79 - 86s - loss: 0.3589 - accuracy: 0.8984 - val_loss: 0.5106 - val_accuracy: 0.8389 - lr: 1.0000e-09 - 86s/epoch - 1s/step

# %% [markdown]
# # Оценим результаты обучения

# %%
loss, accuracy = new_model.evaluate(test_generator,
                                    steps=11,
                                    verbose=2,
                                    use_multiprocessing=True,
                                    workers=2)
print(f'Производительность модели на тестовых изображениях:\nAccuracy = {accuracy}\nLoss = {loss}')
# Out:
# 11/11 - 10s - loss: 0.5658 - accuracy: 0.8146 - 10s/epoch - 864ms/step
# Производительность модели на тестовых изображениях:
# Accuracy = 0.8146417737007141
# Loss = 0.5658105611801147

# %%
# Изменение ошибки во время обучения:
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot(
    title='Изменение ошибки во время обучения',
    grid=True,
    xlabel='Кол-во эпох',
    ylabel='Значение ошибки'
    );

# %%
# Изменение accuracy во время обучения
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot(
    title='Изменение accuracy во время обучения',
    grid=True,
    xlabel='Кол-во эпох',
    ylabel='Значение accuracy'
);

# %% [markdown]
# # Выводы
# * Исходный датасет для обучения содержит около 4500 фотографий грибов, разбитых на 9 классов по признаку "тип гриба"
# * Датасет был разделен на train, validation и tets выборки в пропорции 75%/15%/10%
# * С помощью ImageDataGenerator на основе выборок train, validation и tets созданы наборы данных для обучения модели
# * Для классификации взята предобученная модель EfficientNetB7 в которую мы добавили 1 финальный слой
# * Лучшие показатели метрик Accuracy = 0.81 и Loss = 0.56

# %% [markdown]
# # Записываем модель в .pkl для использования на backend tg бота

# %%
import pickle

pickle.dump(new_model, open("model.pkl", "wb"))
